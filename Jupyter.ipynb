# %%
from draw_plots import draw_plots # import from draw_plost this main function draw_plats
from IPython.display import Image # import displaying image from Ipython

# %%
filepath = draw_plots('deviation.json') # display and create new folder with plot

# %%
Image(filename=filepath)
