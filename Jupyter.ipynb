# %%
from draw_plots import Plots # import from draw_plost this main function draw_plats
from IPython.display import Image # import displaying image from Ipython

# %%
output = Plots() # connecting class to output for getting access to the displaying plots
paths = output.draw_plots('deviation.json') # paths from deviation

# %%
for path in paths:
    display(Image(filename=path))
